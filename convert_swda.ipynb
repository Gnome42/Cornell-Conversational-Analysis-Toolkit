# %% [markdown]
# ### Converting the Switchboard dataset into Convokit format

# %%
from convokit import Corpus, User, Utterance
from swda import Transcript
import glob

# %% [markdown]
# #### Creating Users
#
# Each caller is considered a user, and there are total of 440 different callers in this dataset. Each user is marked with a numerical id, and the metadata for each user includes the following information:
#
# - Gender (str): MALE or FEMALE
# - Education (int): 0, 1, 2, 3, 9
# - Birth Year (int): YYYY
# - Dialect Area (str): MIXED, NEW ENGLAND, NORTH MIDLAND, NORTHERN, NYC, SOUTH MIDLAND, SOUTHERN, UNK, WESTERN

# %%
files = glob.glob("./swda/*/sw_*.utt.csv") # Switchboard utterance files
user_meta = {}

for file in files:
    trans = Transcript(file, './swda/swda-metadata.csv')
    user_meta[trans.from_caller] = {"sex": trans.from_caller_sex,
                                    "education": trans.from_caller_education,
                                    "birth_year": trans.from_caller_birth_year,
                                    "dialect_area": trans.from_caller_dialect_area}
    user_meta[trans.to_caller] = {"sex": trans.to_caller_sex,
                                    "education": trans.to_caller_education,
                                    "birth_year": trans.to_caller_birth_year,
                                    "dialect_area": trans.to_caller_dialect_area}

# %% [markdown]
# Create a User object for each unique user in the dataset

# %%
corpus_users = {k: User(name = k, meta = v) for k,v in user_meta.items()}

# %% [markdown]
# Check number of users in the dataset

# %%
print("Number of users in the data = {}".format(len(corpus_users)))
# Out:
# Number of users in the data = 440

# %%
# Example metadata from user 1632
corpus_users[1632].meta
# Out:
# {'sex': 'FEMALE',
#  'education': 2,
#  'birth_year': 1962,
#  'dialect_area': 'WESTERN'}

# %% [markdown]
# #### Creating Utterances
#
# Utterances are found in the "text" field of each Transcript object. There are 221,616 utterances in total.
#
# Each Utterance object has the following fields:
#
# - id: the unique id of the utterance
# - user: the User giving the utterance
# - root: id of the root utterance of the conversation
# - reply_to: id of the utterance this replies to
# - timestamp: timestamp of the utterance (not applicable in Switchboard)
# - text: text of the utterance
# - tag: the DAMSL act-tag of the utterance
# - pos: the part-of-speech tagged portion of the utterance

# %%
utterance_corpus = {}

# Iterate thru each transcript
for file in files:
    
    trans = Transcript(file, './swda/swda-metadata.csv')
    utts = trans.utterances
    root = str(trans.conversation_no) + "-0" # Get id of root utterance
    
    # Iterate thru each utterance in transcript
    for utt in utts:
        
        idx = str(utt.conversation_no) + "-" + str(utt.transcript_index)
        text = utt.text
        
        # Check which user is talking
        if 'A' in utt.caller:
            user = trans.from_caller
        else:
            user = trans.to_caller
        
        # Put act-tag and POS information into metadata
        meta = {'tag': utt.act_tag,
                'pos': utt.pos}
    
        # Check id of previous utterance
        if utt.transcript_index == 0:
            reply_to = None
        else:
            reply_to = str(utt.conversation_no) + "-" + str(utt.transcript_index-1)
            
        utterance_corpus[idx] = Utterance(idx, corpus_users[user], root,
                                          reply_to, None, text, meta)

# %%
utterance_list = [utterance for k,utterance in utterance_corpus.items()]

# %% [markdown]
# Check number of utterances in the dataset

# %%
print("Number of utterances in the data = {}".format(len(utterance_corpus)))
# Out:
# Number of utterances in the data = 221616

# %%
# Example utterance object
utterance_corpus['4325-0']
# Out:
# Utterance({'id': '4325-0', 'user': User([('name', 1632)]), 'root': 4325, 'reply_to': None, 'timestamp': None, 'text': 'Okay.  /', 'meta': {'tag': 'o', 'pos': 'Okay/UH ./.'}})

# %% [markdown]
# #### Creating corpus from list of utterances

# %%
swda_corpus = Corpus(utterances=utterance_list, version=1)

# %%
print("number of conversations in the dataset = {}".format(len(swda_corpus.get_conversation_ids())))
# Out:
# number of conversations in the dataset = 1155

# %%
convo_ids = swda_corpus.get_conversation_ids()
for i, convo_idx in enumerate(convo_ids[0:2]):
    print("sample conversation {}:".format(i))
    print(swda_corpus.get_conversation(convo_idx).get_utterance_ids())
# Out:
# sample conversation 0:
# ['4325-0', '4325-1', '4325-2', '4325-3', '4325-4', '4325-5', '4325-6', '4325-7', '4325-8', '4325-9', '4325-10', '4325-11', '4325-12', '4325-13', '4325-14', '4325-15', '4325-16', '4325-17', '4325-18', '4325-19', '4325-20', '4325-21', '4325-22', '4325-23', '4325-24', '4325-25', '4325-26', '4325-27', '4325-28', '4325-29', '4325-30', '4325-31', '4325-32', '4325-33', '4325-34', '4325-35', '4325-36', '4325-37', '4325-38', '4325-39', '4325-40', '4325-41', '4325-42', '4325-43', '4325-44', '4325-45', '4325-46', '4325-47', '4325-48', '4325-49', '4325-50', '4325-51', '4325-52', '4325-53', '4325-54', '4325-55', '4325-56', '4325-57', '4325-58', '4325-59', '4325-60', '4325-61', '4325-62', '4325-63', '4325-64', '4325-65', '4325-66', '4325-67', '4325-68', '4325-69', '4325-70', '4325-71', '4325-72', '4325-73', '4325-74', '4325-75', '4325-76', '4325-77', '4325-78', '4325-79', '4325-80', '4325-81', '4325-82', '4325-83', '4325-84', '4325-85', '4325-86', '4325-87', '4325-88', '4325-89', '4325-90', '4325-91', '4325-92', '4325-93', '4325-94', '4325-95', '4325-96', '4325-97', '4325-98', '4325-99', '4325-100', '4325-101', '4325-102', '4325-103', '4325-104', '4325-105', '4325-106', '4325-107', '4325-108', '4325-109', '4325-110', '4325-111', '4325-112', '4325-113', '4325-114', '4325-115', '4325-116', '4325-117', '4325-118', '4325-119', '4325-120', '4325-121', '4325-122', '4325-123', '4325-124', '4325-125', '4325-126', '4325-127', '4325-128', '4325-129', '4325-130', '4325-131', '4325-132', '4325-133', '4325-134', '4325-135', '4325-136', '4325-137', '4325-138', '4325-139', '4325-140', '4325-141', '4325-142', '4325-143', '4325-144', '4325-145', '4325-146', '4325-147', '4325-148', '4325-149', '4325-150', '4325-151', '4325-152', '4325-153', '4325-154', '4325-155', '4325-156', '4325-157', '4325-158']
# sample conversation 1:
# ['4330-0', '4330-1', '4330-2', '4330-3', '4330-4', '4330-5', '4330-6', '4330-7', '4330-8', '4330-9', '4330-10', '4330-11', '4330-12', '4330-13', '4330-14', '4330-15', '4330-16', '4330-17', '4330-18', '4330-19', '4330-20', '4330-21', '4330-22', '4330-23', '4330-24', '4330-25', '4330-26', '4330-27', '4330-28', '4330-29', '4330-30', '4330-31', '4330-32', '4330-33', '4330-34', '4330-35', '4330-36', '4330-37', '4330-38', '4330-39', '4330-40', '4330-41', '4330-42', '4330-43', '4330-44', '4330-45', '4330-46', '4330-47', '4330-48', '4330-49', '4330-50', '4330-51', '4330-52', '4330-53', '4330-54', '4330-55', '4330-56', '4330-57', '4330-58', '4330-59', '4330-60', '4330-61', '4330-62', '4330-63', '4330-64', '4330-65', '4330-66', '4330-67', '4330-68', '4330-69', '4330-70', '4330-71', '4330-72', '4330-73', '4330-74', '4330-75', '4330-76', '4330-77', '4330-78', '4330-79', '4330-80', '4330-81', '4330-82', '4330-83', '4330-84', '4330-85', '4330-86', '4330-87', '4330-88', '4330-89', '4330-90', '4330-91', '4330-92', '4330-93', '4330-94', '4330-95', '4330-96', '4330-97', '4330-98', '4330-99', '4330-100', '4330-101', '4330-102', '4330-103', '4330-104', '4330-105', '4330-106', '4330-107', '4330-108', '4330-109']

# %% [markdown]
# #### Updating corpus level metadata

# %%
swda_meta = {}
for file in files:
    trans = Transcript(file, './swda/swda-metadata.csv')
    idx = trans.conversation_no
    swda_meta[idx] = {}
    swda_meta[idx]['filename'] = trans.ptd_basename
    swda_meta[idx]['talk_day'] = trans.talk_day
    swda_meta[idx]['topic_description'] = trans.topic_description
    swda_meta[idx]['length'] = trans.length
    swda_meta[idx]['prompt'] = trans.prompt
                     
    
swda_corpus.meta['metadata'] = swda_meta
swda_corpus.meta['name'] = "The Switchboard Dialog Act Corpus"

# %%
swda_corpus.meta
# Out:
# {'name': 'The Switchboard Dialog Act Corpus',
#  'metadata': {4325: {'filename': '4/sw4325',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'CHILD CARE',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT CRITERIA THE OTHER CALLER WOULD USE IN SELECTING CHILD CARE SERVICES FOR A PRESCHOOLER.  IS IT EASY OR DIFFICULT TO FIND SUCH CARE?'},
#   4330: {'filename': '4/sw4330',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 5,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   4103: {'filename': '4/sw4103',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4327: {'filename': '4/sw4327',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4646: {'filename': '4/sw4646',
#    'talk_day': datetime.datetime(1992, 4, 10, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4108: {'filename': '4/sw4108',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4171: {'filename': '4/sw4171',
#    'talk_day': datetime.datetime(1992, 3, 12, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4321: {'filename': '4/sw4321',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4329: {'filename': '4/sw4329',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 4,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4356: {'filename': '4/sw4356',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   4358: {'filename': '4/sw4358',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4360: {'filename': '4/sw4360',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'SOCIAL CHANGE',
#    'length': 5,
#    'prompt': 'DISCUSS RECENT SOCIAL CHANGES.  HOW IS LIFE IN AMERICA DIFFERENT TODAY COMPARED TO LIVING TENY'},
#   4617: {'filename': '4/sw4617',
#    'talk_day': datetime.datetime(1992, 4, 8, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4619: {'filename': '4/sw4619',
#    'talk_day': datetime.datetime(1992, 4, 8, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4877: {'filename': '4/sw4877',
#    'talk_day': datetime.datetime(1992, 4, 30, 0, 0),
#    'topic_description': 'CHILD CARE',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT CRITERIA THE OTHER CALLER WOULD USE IN SELECTING CHILD CARE SERVICES FOR A PRESCHOOLER.  IS IT EASY OR DIFFICULT TO FIND SUCH CARE?'},
#   3389: {'filename': '3/sw3389',
#    'talk_day': datetime.datetime(1991, 11, 12, 0, 0),
#    'topic_description': 'FOOTBALL',
#    'length': 5,
#    'prompt': "PLEASE DISCUSS PROFESSIONAL FOOTBALL.  FIND OUT THE OTHER CALLER'S FAVORITE PRO FOOTBALL TEAM AND WHERE IT'S HEADED THIS YEAR.       DO YOU AGREE WITH THE CALLER'S PREDICTION?"},
#   4036: {'filename': '4/sw4036',
#    'talk_day': datetime.datetime(1992, 3, 2, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4082: {'filename': '4/sw4082',
#    'talk_day': datetime.datetime(1992, 3, 7, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4104: {'filename': '4/sw4104',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4109: {'filename': '4/sw4109',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4168: {'filename': '4/sw4168',
#    'talk_day': datetime.datetime(1992, 3, 12, 0, 0),
#    'topic_description': 'MUSIC',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS MUSIC.  CAN YOU FIND MUSICIANSOR TYPES OF MUSIC THAT BOTH YOU AND THE OTHER CALLER LIKE?'},
#   4320: {'filename': '4/sw4320',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'CRIME',
#    'length': 5,
#    'prompt': 'DISCUSS CRIME IN AMERICAN CITIES TODAY.  WHAT ARE YOUR CONCERNS AND THE CONCERNS OF THE OTHER CALLER?  WHAT STEPS CAN BE TAKEN TO REDUCE CRIME?'},
#   4341: {'filename': '4/sw4341',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'CAPITAL PUNISHMENT',
#    'length': 5,
#    'prompt': 'COMPARE YOUR OPINIONS AND THOSE OF THE OTHER CALLER ON CAPITAL PUNISHMENT.  DO EITHER OF YOU THINK IT SHOULD BE RESTRICTED TO CERTAIN CRIMES OR CIRCUMSTANCES?  HOW DO THE POLICIES AND PRACTICES OF YOUR STATE FIT WITH YOUR OPINIONS?'},
#   4688: {'filename': '4/sw4688',
#    'talk_day': datetime.datetime(1992, 4, 14, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   2451: {'filename': '2/sw2451',
#    'talk_day': datetime.datetime(1991, 4, 5, 0, 0),
#    'topic_description': 'SOVIET UNION',
#    'length': 2,
#    'prompt': 'FIND OUT WHETHER OR NOT THE OTHER CALLER CONSIDERS THE SOVIET UNION A THREAT TO THE UNITED STATES.   TAKE AN OPPOSING VIEW IN YOUR DISCUSSION WITH THE OTHER CALLER.'},
#   3902: {'filename': '3/sw3902',
#    'talk_day': datetime.datetime(1992, 2, 3, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4096: {'filename': '4/sw4096',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4133: {'filename': '4/sw4133',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'CAPITAL PUNISHMENT',
#    'length': 5,
#    'prompt': 'COMPARE YOUR OPINIONS AND THOSE OF THE OTHER CALLER ON CAPITAL PUNISHMENT.  DO EITHER OF YOU THINK IT SHOULD BE RESTRICTED TO CERTAIN CRIMES OR CIRCUMSTANCES?  HOW DO THE POLICIES AND PRACTICES OF YOUR STATE FIT WITH YOUR OPINIONS?'},
#   4152: {'filename': '4/sw4152',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4166: {'filename': '4/sw4166',
#    'talk_day': datetime.datetime(1992, 3, 12, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4319: {'filename': '4/sw4319',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4333: {'filename': '4/sw4333',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'TAXES',
#    'length': 5,
#    'prompt': 'TALK ABOUT WHETHER AMERICANSY'},
#   4336: {'filename': '4/sw4336',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'CRIME',
#    'length': 5,
#    'prompt': 'DISCUSS CRIME IN AMERICAN CITIES TODAY.  WHAT ARE YOUR CONCERNS AND THE CONCERNS OF THE OTHER CALLER?  WHAT STEPS CAN BE TAKEN TO REDUCE CRIME?'},
#   4345: {'filename': '4/sw4345',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4372: {'filename': '4/sw4372',
#    'talk_day': datetime.datetime(1992, 3, 25, 0, 0),
#    'topic_description': 'TAXES',
#    'length': 5,
#    'prompt': 'TALK ABOUT WHETHER AMERICANSY'},
#   4379: {'filename': '4/sw4379',
#    'talk_day': datetime.datetime(1992, 3, 25, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4382: {'filename': '4/sw4382',
#    'talk_day': datetime.datetime(1992, 3, 25, 0, 0),
#    'topic_description': 'AIR POLLUTION',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS AIR POLLUTION.  FIND OUT WHAT SUBSTANCES THE OTHER CALLER THINKS CONTRIBUTE THE MOST TO AIR POLLUTION TODAY.  WHAT CAN INDIVIDUALS OR SOCIETY DO TO IMPROVE AIR QUALITY?'},
#   4611: {'filename': '4/sw4611',
#    'talk_day': datetime.datetime(1992, 4, 8, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4628: {'filename': '4/sw4628',
#    'talk_day': datetime.datetime(1992, 4, 9, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 6,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   2095: {'filename': '2/sw2095',
#    'talk_day': datetime.datetime(1991, 3, 10, 0, 0),
#    'topic_description': 'WEATHER CLIMATE',
#    'length': 5,
#    'prompt': "DISCUSS THE WEATHER.   WHAT HAS IT BEEN LIKE IN YOUR AREA?   HAS IT BEEN TYPICAL FOR THIS TIME OF YEAR?  COMPARE IT WITH THE OTHER CALLER'S WEATHER."},
#   4048: {'filename': '4/sw4048',
#    'talk_day': datetime.datetime(1992, 3, 3, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 5,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   4060: {'filename': '4/sw4060',
#    'talk_day': datetime.datetime(1992, 3, 4, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4148: {'filename': '4/sw4148',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4177: {'filename': '4/sw4177',
#    'talk_day': datetime.datetime(1992, 3, 13, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4312: {'filename': '4/sw4312',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'MUSIC',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS MUSIC.  CAN YOU FIND MUSICIANSOR TYPES OF MUSIC THAT BOTH YOU AND THE OTHER CALLER LIKE?'},
#   4316: {'filename': '4/sw4316',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'CRIME',
#    'length': 5,
#    'prompt': 'DISCUSS CRIME IN AMERICAN CITIES TODAY.  WHAT ARE YOUR CONCERNS AND THE CONCERNS OF THE OTHER CALLER?  WHAT STEPS CAN BE TAKEN TO REDUCE CRIME?'},
#   4339: {'filename': '4/sw4339',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   4340: {'filename': '4/sw4340',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'CRIME',
#    'length': 5,
#    'prompt': 'DISCUSS CRIME IN AMERICAN CITIES TODAY.  WHAT ARE YOUR CONCERNS AND THE CONCERNS OF THE OTHER CALLER?  WHAT STEPS CAN BE TAKEN TO REDUCE CRIME?'},
#   4353: {'filename': '4/sw4353',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4362: {'filename': '4/sw4362',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'PUBLIC EDUCATION',
#    'length': 5,
#    'prompt': 'DISCUSS WITH THE OTHER CALLER WHETHER THERE IS SOMETHING SERIOUSLY WRONG WITH OUR PUBLIC SCHOOL SYSTEMS TODAYY'},
#   4364: {'filename': '4/sw4364',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'RIGHT TO PRIVACY',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT EVERYDAY OCCURRENCES THE OTHER CALLER CONSIDERS TO BE AN INTRUSION OF PRIVACY.  WHAT CAN BE DONE TO PREVENT THEM?  DO YOU AGREE OR DISAGREE?'},
#   4378: {'filename': '4/sw4378',
#    'talk_day': datetime.datetime(1992, 3, 25, 0, 0),
#    'topic_description': 'HOME REPAIRS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT THE LAST HOME REPAIR OR REMODELING PROJECT THE OTHER CALLERUNDERTOOK.  HOW SUCCESSFUL WAS IT?  HOW DOES IT COMPARE TO YOUR OWN EXPERIENCE?'},
#   2184: {'filename': '2/sw2184',
#    'talk_day': datetime.datetime(1991, 3, 19, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 10,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   2789: {'filename': '2/sw2789',
#    'talk_day': datetime.datetime(1991, 5, 4, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 10,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   3156: {'filename': '3/sw3156',
#    'talk_day': datetime.datetime(1991, 9, 24, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   3351: {'filename': '3/sw3351',
#    'talk_day': datetime.datetime(1991, 11, 3, 0, 0),
#    'topic_description': 'PETS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   3506: {'filename': '3/sw3506',
#    'talk_day': datetime.datetime(1991, 12, 10, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   3707: {'filename': '3/sw3707',
#    'talk_day': datetime.datetime(1992, 1, 8, 0, 0),
#    'topic_description': 'PETS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   4028: {'filename': '4/sw4028',
#    'talk_day': datetime.datetime(1992, 3, 1, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4038: {'filename': '4/sw4038',
#    'talk_day': datetime.datetime(1992, 3, 2, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4151: {'filename': '4/sw4151',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'CAPITAL PUNISHMENT',
#    'length': 5,
#    'prompt': 'COMPARE YOUR OPINIONS AND THOSE OF THE OTHER CALLER ON CAPITAL PUNISHMENT.  DO EITHER OF YOU THINK IT SHOULD BE RESTRICTED TO CERTAIN CRIMES OR CIRCUMSTANCES?  HOW DO THE POLICIES AND PRACTICES OF YOUR STATE FIT WITH YOUR OPINIONS?'},
#   4158: {'filename': '4/sw4158',
#    'talk_day': datetime.datetime(1992, 3, 12, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4334: {'filename': '4/sw4334',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'MUSIC',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS MUSIC.  CAN YOU FIND MUSICIANSOR TYPES OF MUSIC THAT BOTH YOU AND THE OTHER CALLER LIKE?'},
#   4346: {'filename': '4/sw4346',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'PUBLIC EDUCATION',
#    'length': 5,
#    'prompt': 'DISCUSS WITH THE OTHER CALLER WHETHER THERE IS SOMETHING SERIOUSLY WRONG WITH OUR PUBLIC SCHOOL SYSTEMS TODAYY'},
#   4349: {'filename': '4/sw4349',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'AUTO REPAIRS',
#    'length': 5,
#    'prompt': 'WHAT WAS THE LAST AUTO REPAIR YOU PERFORMED OR HAD DONE ON YOUR CAR? ARE THERE SOME TYPES OF REPAIRS OR MAINTENANCE TASKS YOU PREFER TO DO YOURSELF?  DISCUSS YOUR EXPERIENCES IN THIS AREA WITH THE OTHER CALLER.'},
#   2593: {'filename': '2/sw2593',
#    'talk_day': datetime.datetime(1991, 4, 13, 0, 0),
#    'topic_description': 'HOBBIES AND CRAFTS',
#    'length': 10,
#    'prompt': 'WHAT HOBBIES DO YOU HAVE IN YOUR SPARE TIME?  DO THEY INCLUDE ANY HANDICRAFTSWOODWORKING?'},
#   2945: {'filename': '2/sw2945',
#    'talk_day': datetime.datetime(1991, 5, 21, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 8,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   3075: {'filename': '3/sw3075',
#    'talk_day': datetime.datetime(1991, 6, 16, 0, 0),
#    'topic_description': 'VACATION SPOTS',
#    'length': 7,
#    'prompt': "PLEASE DISCUSS TYPES OF VACATIONS AND TRIPS YOU ENJOY.  FIND OUT WHETHER THE OTHER CALLER CAN INTEREST YOU IN A VACATION SPOT YOU HAVEN'T VISITED."},
#   3144: {'filename': '3/sw3144',
#    'talk_day': datetime.datetime(1991, 7, 18, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 8,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   3435: {'filename': '3/sw3435',
#    'talk_day': datetime.datetime(1991, 11, 27, 0, 0),
#    'topic_description': 'GOLF',
#    'length': 5,
#    'prompt': 'DISCUSS GOLF. ARE YOU A SPECTATOR OR A PLAYER?  WHAT ARE THE ASPECTS OF THE GAME THAT YOU THINK ARE MOST CHALLENGING?  WHAT DO YOU ENJOY THE MOST ABOUT PLAYING OR WATCHING GOLF?'},
#   3658: {'filename': '3/sw3658',
#    'talk_day': datetime.datetime(1992, 1, 2, 0, 0),
#    'topic_description': 'UNIVERSAL HEALTH INS',
#    'length': 5,
#    'prompt': 'DO YOU BELIEVE THAT THE US GOVERNMENT SHOULD PROVIDE UNIVERSAL HEALTH INSURANCE'},
#   3876: {'filename': '3/sw3876',
#    'talk_day': datetime.datetime(1992, 1, 30, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4049: {'filename': '4/sw4049',
#    'talk_day': datetime.datetime(1992, 3, 3, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 5,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   4127: {'filename': '4/sw4127',
#    'talk_day': datetime.datetime(1992, 3, 10, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4129: {'filename': '4/sw4129',
#    'talk_day': datetime.datetime(1992, 3, 10, 0, 0),
#    'topic_description': 'CAPITAL PUNISHMENT',
#    'length': 5,
#    'prompt': 'COMPARE YOUR OPINIONS AND THOSE OF THE OTHER CALLER ON CAPITAL PUNISHMENT.  DO EITHER OF YOU THINK IT SHOULD BE RESTRICTED TO CERTAIN CRIMES OR CIRCUMSTANCES?  HOW DO THE POLICIES AND PRACTICES OF YOUR STATE FIT WITH YOUR OPINIONS?'},
#   4153: {'filename': '4/sw4153',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'CHILD CARE',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT CRITERIA THE OTHER CALLER WOULD USE IN SELECTING CHILD CARE SERVICES FOR A PRESCHOOLER.  IS IT EASY OR DIFFICULT TO FIND SUCH CARE?'},
#   4155: {'filename': '4/sw4155',
#    'talk_day': datetime.datetime(1992, 3, 12, 0, 0),
#    'topic_description': 'TAXES',
#    'length': 5,
#    'prompt': 'TALK ABOUT WHETHER AMERICANSY'},
#   4181: {'filename': '4/sw4181',
#    'talk_day': datetime.datetime(1992, 3, 13, 0, 0),
#    'topic_description': 'TAXES',
#    'length': 5,
#    'prompt': 'TALK ABOUT WHETHER AMERICANSY'},
#   4318: {'filename': '4/sw4318',
#    'talk_day': datetime.datetime(1992, 3, 22, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   4366: {'filename': '4/sw4366',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   4380: {'filename': '4/sw4380',
#    'talk_day': datetime.datetime(1992, 3, 25, 0, 0),
#    'topic_description': 'PUBLIC EDUCATION',
#    'length': 5,
#    'prompt': 'DISCUSS WITH THE OTHER CALLER WHETHER THERE IS SOMETHING SERIOUSLY WRONG WITH OUR PUBLIC SCHOOL SYSTEMS TODAYY'},
#   4626: {'filename': '4/sw4626',
#    'talk_day': datetime.datetime(1992, 4, 9, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4830: {'filename': '4/sw4830',
#    'talk_day': datetime.datetime(1992, 4, 26, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   2109: {'filename': '2/sw2109',
#    'talk_day': datetime.datetime(1991, 3, 11, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 7,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   2395: {'filename': '2/sw2395',
#    'talk_day': datetime.datetime(1991, 4, 2, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 10,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   2546: {'filename': '2/sw2546',
#    'talk_day': datetime.datetime(1991, 4, 10, 0, 0),
#    'topic_description': 'CAPITAL PUNISHMENT',
#    'length': 7,
#    'prompt': 'COMPARE YOUR OPINIONS AND THOSE OF THE OTHER CALLER ON CAPITAL PUNISHMENT.  DO EITHER OF YOU THINK IT SHOULD BE RESTRICTED TO CERTAIN CRIMES OR CIRCUMSTANCES?  HOW DO THE POLICIES AND PRACTICES OF YOUR STATE FIT WITH YOUR OPINIONS?'},
#   2775: {'filename': '2/sw2775',
#    'talk_day': datetime.datetime(1991, 5, 3, 0, 0),
#    'topic_description': 'HOUSES',
#    'length': 5,
#    'prompt': "FIND OUT ABOUT THE OTHER CALLER'S HOME.  IS IT A TYPICAL HOME FOR THE AREA?  HOW DOES IT COMPARE TO YOUR HOME?"},
#   3073: {'filename': '3/sw3073',
#    'talk_day': datetime.datetime(1991, 6, 15, 0, 0),
#    'topic_description': 'TV PROGRAMS',
#    'length': 6,
#    'prompt': "FIND OUT WHAT THE OTHER CALLER'S FAVORITE TV SHOWS ARE AND WHY.  ARE YOUR INTERESTS SIMILAR OR DIFFERENT?"},
#   3086: {'filename': '3/sw3086',
#    'talk_day': datetime.datetime(1991, 6, 18, 0, 0),
#    'topic_description': 'COMPUTERS',
#    'length': 7,
#    'prompt': "FIND OUT THE OTHER CALLERS' PREFERENCE AND LEVEL OF INTEREST IN PERSONAL COMPUTERS.  HOW DOES IT COMPARE TO YOUR INTEREST AND PREFERENCE?"},
#   3133: {'filename': '3/sw3133',
#    'talk_day': datetime.datetime(1991, 7, 10, 0, 0),
#    'topic_description': 'UNIVERSAL PBLIC SERV',
#    'length': 5,
#    'prompt': 'SEE HOW THE OTHER CALLER FEELS ABOUT THE PROPOSAL THAT ALL YOUNG AMERICANS SHOULD SPEND A YEAR OR TWO DOING SOME KIND OF PUBLIC SERVICE'},
#   3135: {'filename': '3/sw3135',
#    'talk_day': datetime.datetime(1991, 7, 15, 0, 0),
#    'topic_description': 'CHILD CARE',
#    'length': 8,
#    'prompt': 'FIND OUT WHAT CRITERIA THE OTHER CALLER WOULD USE IN SELECTING CHILD CARE SERVICES FOR A PRESCHOOLER.  IS IT EASY OR DIFFICULT TO FIND SUCH CARE?'},
#   3154: {'filename': '3/sw3154',
#    'talk_day': datetime.datetime(1991, 7, 26, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 8,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   3227: {'filename': '3/sw3227',
#    'talk_day': datetime.datetime(1991, 10, 8, 0, 0),
#    'topic_description': 'MUSIC',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS MUSIC.  CAN YOU FIND MUSICIANSOR TYPES OF MUSIC THAT BOTH YOU AND THE OTHER CALLER LIKE?'},
#   3315: {'filename': '3/sw3315',
#    'talk_day': datetime.datetime(1991, 10, 26, 0, 0),
#    'topic_description': 'TV PROGRAMS',
#    'length': 5,
#    'prompt': "FIND OUT WHAT THE OTHER CALLER'S FAVORITE TV SHOWS ARE AND WHY.  ARE YOUR INTERESTS SIMILAR OR DIFFERENT?"},
#   3445: {'filename': '3/sw3445',
#    'talk_day': datetime.datetime(1991, 12, 2, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   3580: {'filename': '3/sw3580',
#    'talk_day': datetime.datetime(1991, 12, 17, 0, 0),
#    'topic_description': 'SPACE FLIGHT AND EXPLORATION',
#    'length': 5,
#    'prompt': 'WHAT DO WE GAIN FROM OUR SPACE FLIGHT AND EXPLORATION EFFORTS? SHOULD WE CONTINUE TO SUPPORT THE SPACE PROGRAM AT CURRENT LEVELS? YOU MIGHT ALSO DISCUSS WHETHER SPACE FLIGHT WILL EVER BECOME COMMONYOU'},
#   3798: {'filename': '3/sw3798',
#    'talk_day': datetime.datetime(1992, 1, 19, 0, 0),
#    'topic_description': 'AIDS',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS FUNDING FOR AIDS RESEARCH.  SHOULD THE US SPEND MOREY'},
#   3830: {'filename': '3/sw3830',
#    'talk_day': datetime.datetime(1992, 1, 23, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   3917: {'filename': '3/sw3917',
#    'talk_day': datetime.datetime(1992, 2, 5, 0, 0),
#    'topic_description': "WOMEN'S ROLES",
#    'length': 5,
#    'prompt': 'DISCUSS THE CHANGES IN THE ROLES OF WOMEN IN AMERICAN SOCIETY OVER THE PAST GENERATION OR TWO.  WHICH CHANGES HAVE BEEN THE MOST SIGNIFICANT? DO YOU HAVE AN OPINION ON WHAT FURTHER CHANGES WILL TAKE PLACE OVER THE NEXT GENERATION?'},
#   3925: {'filename': '3/sw3925',
#    'talk_day': datetime.datetime(1992, 2, 6, 0, 0),
#    'topic_description': 'ETHICS IN GOVERNMENT',
#    'length': 5,
#    'prompt': 'DO YOU THINK IT IS POSSIBLE TO HAVE AN HONEST GOVERNMENT? ARE MOST POLITICIANS IN GOVERNMENT MORE FOR PERSONAL GAIN OR PUBLIC SERVICE?  HOW MUCH SELF-SERVING ACTIVITY DO YOU THINK GOES ON? IS IT POSSIBLE  TO MAKEBEHAVIOR IN GOVERNMENT ILLEGAL?'},
#   4019: {'filename': '4/sw4019',
#    'talk_day': datetime.datetime(1992, 2, 27, 0, 0),
#    'topic_description': 'PETS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   4033: {'filename': '4/sw4033',
#    'talk_day': datetime.datetime(1992, 3, 2, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4074: {'filename': '4/sw4074',
#    'talk_day': datetime.datetime(1992, 3, 5, 0, 0),
#    'topic_description': 'PETS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   4101: {'filename': '4/sw4101',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4123: {'filename': '4/sw4123',
#    'talk_day': datetime.datetime(1992, 3, 10, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4137: {'filename': '4/sw4137',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   4150: {'filename': '4/sw4150',
#    'talk_day': datetime.datetime(1992, 3, 11, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 5,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   4175: {'filename': '4/sw4175',
#    'talk_day': datetime.datetime(1992, 3, 13, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4342: {'filename': '4/sw4342',
#    'talk_day': datetime.datetime(1992, 3, 23, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   4880: {'filename': '4/sw4880',
#    'talk_day': datetime.datetime(1992, 5, 1, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 5,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   2018: {'filename': '2/sw2018',
#    'talk_day': datetime.datetime(1991, 3, 6, 0, 0),
#    'topic_description': "WOMEN'S ROLES",
#    'length': 7,
#    'prompt': 'DISCUSS THE CHANGES IN THE ROLES OF WOMEN IN AMERICAN SOCIETY OVER THE PAST GENERATION OR TWO.  WHICH CHANGES HAVE BEEN THE MOST SIGNIFICANT? DO YOU HAVE AN OPINION ON WHAT FURTHER CHANGES WILL TAKE PLACE OVER THE NEXT GENERATION?'},
#   2061: {'filename': '2/sw2061',
#    'talk_day': datetime.datetime(1991, 3, 9, 0, 0),
#    'topic_description': 'CREDIT CARD USE',
#    'length': 10,
#    'prompt': 'PLEASE DISCUSS CREDIT CARDS.  FIND OUT HOW THE OTHER CALLER MAKES USE OF CREDIT CARDS.  HOW DO THEY COMPARE TO YOUR OWN?'},
#   2093: {'filename': '2/sw2093',
#    'talk_day': datetime.datetime(1991, 3, 10, 0, 0),
#    'topic_description': 'HOBBIES AND CRAFTS',
#    'length': 6,
#    'prompt': 'WHAT HOBBIES DO YOU HAVE IN YOUR SPARE TIME?  DO THEY INCLUDE ANY HANDICRAFTSWOODWORKING?'},
#   2107: {'filename': '2/sw2107',
#    'talk_day': datetime.datetime(1991, 3, 11, 0, 0),
#    'topic_description': 'PETS',
#    'length': 9,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   2370: {'filename': '2/sw2370',
#    'talk_day': datetime.datetime(1991, 4, 1, 0, 0),
#    'topic_description': "WOMEN'S ROLES",
#    'length': 8,
#    'prompt': 'DISCUSS THE CHANGES IN THE ROLES OF WOMEN IN AMERICAN SOCIETY OVER THE PAST GENERATION OR TWO.  WHICH CHANGES HAVE BEEN THE MOST SIGNIFICANT? DO YOU HAVE AN OPINION ON WHAT FURTHER CHANGES WILL TAKE PLACE OVER THE NEXT GENERATION?'},
#   2406: {'filename': '2/sw2406',
#    'talk_day': datetime.datetime(1991, 4, 3, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 9,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   2837: {'filename': '2/sw2837',
#    'talk_day': datetime.datetime(1991, 5, 9, 0, 0),
#    'topic_description': 'HOME REPAIRS',
#    'length': 10,
#    'prompt': 'FIND OUT WHAT THE LAST HOME REPAIR OR REMODELING PROJECT THE OTHER CALLERUNDERTOOK.  HOW SUCCESSFUL WAS IT?  HOW DOES IT COMPARE TO YOUR OWN EXPERIENCE?'},
#   3080: {'filename': '3/sw3080',
#    'talk_day': datetime.datetime(1991, 6, 18, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 7,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   3083: {'filename': '3/sw3083',
#    'talk_day': datetime.datetime(1991, 6, 18, 0, 0),
#    'topic_description': 'PUBLIC EDUCATION',
#    'length': 6,
#    'prompt': 'DISCUSS WITH THE OTHER CALLER WHETHER THERE IS SOMETHING SERIOUSLY WRONG WITH OUR PUBLIC SCHOOL SYSTEMS TODAYY'},
#   3113: {'filename': '3/sw3113',
#    'talk_day': datetime.datetime(1991, 6, 27, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 8,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   3140: {'filename': '3/sw3140',
#    'talk_day': datetime.datetime(1991, 7, 17, 0, 0),
#    'topic_description': 'SOCIAL CHANGE',
#    'length': 8,
#    'prompt': 'DISCUSS RECENT SOCIAL CHANGES.  HOW IS LIFE IN AMERICA DIFFERENT TODAY COMPARED TO LIVING TENY'},
#   3161: {'filename': '3/sw3161',
#    'talk_day': datetime.datetime(1991, 9, 25, 0, 0),
#    'topic_description': 'AIDS',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS FUNDING FOR AIDS RESEARCH.  SHOULD THE US SPEND MOREY'},
#   3186: {'filename': '3/sw3186',
#    'talk_day': datetime.datetime(1991, 10, 1, 0, 0),
#    'topic_description': 'RESTAURANTS',
#    'length': 5,
#    'prompt': "WHAT KIND OF DINING OUT DO YOU ENJOY? WHAT THINGS DO YOU LOOK FOR IN A RESTAURANT THAT WOULD GET YOU TO GO BACK AGAIN?  SEE WHETHER THE OTHER CALLER'S PREFERENCES ARE SIMILAR TO YOURS."},
#   3201: {'filename': '3/sw3201',
#    'talk_day': datetime.datetime(1991, 10, 3, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   3306: {'filename': '3/sw3306',
#    'talk_day': datetime.datetime(1991, 10, 24, 0, 0),
#    'topic_description': 'BOATING AND SAILING',
#    'length': 5,
#    'prompt': 'DO YOU SAIL OR ENJOY SOME OTHER FORM OF BOATING? DO YOU HAVE YOUR OWN BOAT? FIND OUT WHAT THE OTHER CALLER ENJOYS OR THINKS ABOUT BOATING OR SAILING. OR YOU MIGHT DISCUSS THE PROS AND CONS OF BOAT OWNERSHIP.'},
#   3349: {'filename': '3/sw3349',
#    'talk_day': datetime.datetime(1991, 11, 3, 0, 0),
#    'topic_description': 'HOBBIES AND CRAFTS',
#    'length': 5,
#    'prompt': 'WHAT HOBBIES DO YOU HAVE IN YOUR SPARE TIME?  DO THEY INCLUDE ANY HANDICRAFTSWOODWORKING?'},
#   3411: {'filename': '3/sw3411',
#    'talk_day': datetime.datetime(1991, 11, 17, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   3441: {'filename': '3/sw3441',
#    'talk_day': datetime.datetime(1991, 12, 1, 0, 0),
#    'topic_description': 'RIGHT TO PRIVACY',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT EVERYDAY OCCURRENCES THE OTHER CALLER CONSIDERS TO BE AN INTRUSION OF PRIVACY.  WHAT CAN BE DONE TO PREVENT THEM?  DO YOU AGREE OR DISAGREE?'},
#   3476: {'filename': '3/sw3476',
#    'talk_day': datetime.datetime(1991, 12, 8, 0, 0),
#    'topic_description': 'METRIC SYSTEM',
#    'length': 5,
#    'prompt': 'DO YOU THINK THE UNITED STATES SHOULD ADOPT THE METRIC SYSTEM?  WHY DO YOU THINK THE LAST EFFORT TO ADOPT IT FAILED?  WHAT WOULD HAVE TO BE DONE DIFFERENTLY TO GUARANTEE SUCCESS?'},
#   3514: {'filename': '3/sw3514',
#    'talk_day': datetime.datetime(1991, 12, 11, 0, 0),
#    'topic_description': 'VACATION SPOTS',
#    'length': 5,
#    'prompt': "PLEASE DISCUSS TYPES OF VACATIONS AND TRIPS YOU ENJOY.  FIND OUT WHETHER THE OTHER CALLER CAN INTEREST YOU IN A VACATION SPOT YOU HAVEN'T VISITED."},
#   3561: {'filename': '3/sw3561',
#    'talk_day': datetime.datetime(1991, 12, 16, 0, 0),
#    'topic_description': 'FEDERAL BUDGET',
#    'length': 5,
#    'prompt': 'WHAT SHORT AND LONG-TERM STEPS DO YOU AND THE OTHER CALLER THINK SHOULD BE TAKEN TO IMPROVE THE US BUDGET?'},
#   3682: {'filename': '3/sw3682',
#    'talk_day': datetime.datetime(1992, 1, 5, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   3796: {'filename': '3/sw3796',
#    'talk_day': datetime.datetime(1992, 1, 19, 0, 0),
#    'topic_description': 'BASKETBALL',
#    'length': 5,
#    'prompt': "FIND OUT THE OTHER CALLER'S FAVORITE PRO BASKETBALL TEAM AND WHERE IT'S HEADED THIS YEAR.  DO YOU AGREE WITH THE CALLER'S PREDICTION?"},
#   3887: {'filename': '3/sw3887',
#    'talk_day': datetime.datetime(1992, 1, 31, 0, 0),
#    'topic_description': 'AIR POLLUTION',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS AIR POLLUTION.  FIND OUT WHAT SUBSTANCES THE OTHER CALLER THINKS CONTRIBUTE THE MOST TO AIR POLLUTION TODAY.  WHAT CAN INDIVIDUALS OR SOCIETY DO TO IMPROVE AIR QUALITY?'},
#   4090: {'filename': '4/sw4090',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'FAMILY FINANCE',
#    'length': 5,
#    'prompt': 'DOES YOUR FAMILY KEEP A MONTHLY BUDGETCAN YOU GIVE A GENERAL DESCRIPTION OF YOUR PROCEDURES'},
#   4099: {'filename': '4/sw4099',
#    'talk_day': datetime.datetime(1992, 3, 9, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 5,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   4370: {'filename': '4/sw4370',
#    'talk_day': datetime.datetime(1992, 3, 24, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4890: {'filename': '4/sw4890',
#    'talk_day': datetime.datetime(1992, 5, 2, 0, 0),
#    'topic_description': 'TRIAL BY JURY',
#    'length': 5,
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   4908: {'filename': '4/sw4908',
#    'talk_day': datetime.datetime(1992, 5, 4, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   4928: {'filename': '4/sw4928',
#    'talk_day': datetime.datetime(1992, 5, 6, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 5,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   2060: {'filename': '2/sw2060',
#    'talk_day': datetime.datetime(1991, 3, 9, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 6,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   2145: {'filename': '2/sw2145',
#    'talk_day': datetime.datetime(1991, 3, 13, 0, 0),
#    'topic_description': "WOMEN'S ROLES",
#    'length': 6,
#    'prompt': 'DISCUSS THE CHANGES IN THE ROLES OF WOMEN IN AMERICAN SOCIETY OVER THE PAST GENERATION OR TWO.  WHICH CHANGES HAVE BEEN THE MOST SIGNIFICANT? DO YOU HAVE AN OPINION ON WHAT FURTHER CHANGES WILL TAKE PLACE OVER THE NEXT GENERATION?'},
#   2290: {'filename': '2/sw2290',
#    'talk_day': datetime.datetime(1991, 3, 26, 0, 0),
#    'topic_description': 'FISHING',
#    'length': 10,
#    'prompt': 'FIND OUT WHAT KIND OF FISHING THE OTHER CALLER ENJOYS.  DO YOU HAVE SIMILAR OR DIFFERENT  INTERESTS IN THE KIND OF FISHING YOU ENJOY?'},
#   2399: {'filename': '2/sw2399',
#    'talk_day': datetime.datetime(1991, 4, 2, 0, 0),
#    'topic_description': 'CREDIT CARD USE',
#    'length': 10,
#    'prompt': 'PLEASE DISCUSS CREDIT CARDS.  FIND OUT HOW THE OTHER CALLER MAKES USE OF CREDIT CARDS.  HOW DO THEY COMPARE TO YOUR OWN?'},
#   2429: {'filename': '2/sw2429',
#    'talk_day': datetime.datetime(1991, 4, 4, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 10,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   2477: {'filename': '2/sw2477',
#    'talk_day': datetime.datetime(1991, 4, 6, 0, 0),
#    'topic_description': 'BASKETBALL',
#    'length': 9,
#    'prompt': "FIND OUT THE OTHER CALLER'S FAVORITE PRO BASKETBALL TEAM AND WHERE IT'S HEADED THIS YEAR.  DO YOU AGREE WITH THE CALLER'S PREDICTION?"},
#   2539: {'filename': '2/sw2539',
#    'talk_day': datetime.datetime(1991, 4, 10, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 7,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   2604: {'filename': '2/sw2604',
#    'talk_day': datetime.datetime(1991, 4, 14, 0, 0),
#    'topic_description': 'UNIVERSAL PBLIC SERV',
#    'length': 10,
#    'prompt': 'SEE HOW THE OTHER CALLER FEELS ABOUT THE PROPOSAL THAT ALL YOUNG AMERICANS SHOULD SPEND A YEAR OR TWO DOING SOME KIND OF PUBLIC SERVICE'},
#   2611: {'filename': '2/sw2611',
#    'talk_day': datetime.datetime(1991, 4, 14, 0, 0),
#    'topic_description': 'CLOTHING AND DRESS',
#    'length': 10,
#    'prompt': 'THE TOPIC IS CLOTHING.  PLEASE FIND OUT HOW THE OTHER CALLER TYPICALLY DRESSES FOR WORK.  HOW MUCH VARIATION IS THERE FROM DAY TO DAY?  HOW MUCH VARIATION IS THERE FROM SEASON TO SEASON?'},
#   2628: {'filename': '2/sw2628',
#    'talk_day': datetime.datetime(1991, 4, 22, 0, 0),
#    'topic_description': "WOMEN'S ROLES",
#    'length': 9,
#    'prompt': 'DISCUSS THE CHANGES IN THE ROLES OF WOMEN IN AMERICAN SOCIETY OVER THE PAST GENERATION OR TWO.  WHICH CHANGES HAVE BEEN THE MOST SIGNIFICANT? DO YOU HAVE AN OPINION ON WHAT FURTHER CHANGES WILL TAKE PLACE OVER THE NEXT GENERATION?'},
#   2772: {'filename': '2/sw2772',
#    'talk_day': datetime.datetime(1991, 5, 2, 0, 0),
#    'topic_description': 'WEATHER CLIMATE',
#    'length': 10,
#    'prompt': "DISCUSS THE WEATHER.   WHAT HAS IT BEEN LIKE IN YOUR AREA?   HAS IT BEEN TYPICAL FOR THIS TIME OF YEAR?  COMPARE IT WITH THE OTHER CALLER'S WEATHER."},
#   3108: {'filename': '3/sw3108',
#    'talk_day': datetime.datetime(1991, 6, 21, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 7,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   3138: {'filename': '3/sw3138',
#    'talk_day': datetime.datetime(1991, 7, 16, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 7,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   3142: {'filename': '3/sw3142',
#    'talk_day': datetime.datetime(1991, 7, 17, 0, 0),
#    'topic_description': 'RESTAURANTS',
#    'length': 8,
#    'prompt': "WHAT KIND OF DINING OUT DO YOU ENJOY? WHAT THINGS DO YOU LOOK FOR IN A RESTAURANT THAT WOULD GET YOU TO GO BACK AGAIN?  SEE WHETHER THE OTHER CALLER'S PREFERENCES ARE SIMILAR TO YOURS."},
#   3219: {'filename': '3/sw3219',
#    'talk_day': datetime.datetime(1991, 10, 8, 0, 0),
#    'topic_description': 'CLOTHING AND DRESS',
#    'length': 5,
#    'prompt': 'THE TOPIC IS CLOTHING.  PLEASE FIND OUT HOW THE OTHER CALLER TYPICALLY DRESSES FOR WORK.  HOW MUCH VARIATION IS THERE FROM DAY TO DAY?  HOW MUCH VARIATION IS THERE FROM SEASON TO SEASON?'},
#   3252: {'filename': '3/sw3252',
#    'talk_day': datetime.datetime(1991, 10, 13, 0, 0),
#    'topic_description': 'PETS',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT KIND OF PETS THE OTHER CALLER HAS'},
#   3304: {'filename': '3/sw3304',
#    'talk_day': datetime.datetime(1991, 10, 24, 0, 0),
#    'topic_description': 'HOBBIES AND CRAFTS',
#    'length': 3,
#    'prompt': 'WHAT HOBBIES DO YOU HAVE IN YOUR SPARE TIME?  DO THEY INCLUDE ANY HANDICRAFTSWOODWORKING?'},
#   3327: {'filename': '3/sw3327',
#    'talk_day': datetime.datetime(1991, 10, 29, 0, 0),
#    'topic_description': 'AUTO REPAIRS',
#    'length': 5,
#    'prompt': 'WHAT WAS THE LAST AUTO REPAIR YOU PERFORMED OR HAD DONE ON YOUR CAR? ARE THERE SOME TYPES OF REPAIRS OR MAINTENANCE TASKS YOU PREFER TO DO YOURSELF?  DISCUSS YOUR EXPERIENCES IN THIS AREA WITH THE OTHER CALLER.'},
#   3369: {'filename': '3/sw3369',
#    'talk_day': datetime.datetime(1991, 11, 7, 0, 0),
# ...
#    'prompt': 'DISCUSS POSSIBLE CHANGES IN THE WAY TRIALS BY JURY ARE CONDUCTED.     FOR EXAMPLE'},
#   3151: {'filename': '3/sw3151',
#    'talk_day': datetime.datetime(1991, 7, 25, 0, 0),
#    'topic_description': 'DRUG TESTING',
#    'length': 7,
#    'prompt': 'HOW DO YOU FEEL ABOUT THE PRACTICE OF SOME COMPANIES OR GOVERNMENT AGENCIES TESTING EMPLOYEES OR PROSPECTIVE EMPLOYEES FOR DRUGS?  IS RANDOM SPOT TESTING JUSTIFIED?  WHAT LIMITS SHOULD THERE BE'},
#   3216: {'filename': '3/sw3216',
#    'talk_day': datetime.datetime(1991, 10, 7, 0, 0),
#    'topic_description': 'PUBLIC EDUCATION',
#    'length': 3,
#    'prompt': 'DISCUSS WITH THE OTHER CALLER WHETHER THERE IS SOMETHING SERIOUSLY WRONG WITH OUR PUBLIC SCHOOL SYSTEMS TODAYY'},
#   3221: {'filename': '3/sw3221',
#    'talk_day': datetime.datetime(1991, 10, 8, 0, 0),
#    'topic_description': 'COMPUTERS',
#    'length': 5,
#    'prompt': "FIND OUT THE OTHER CALLERS' PREFERENCE AND LEVEL OF INTEREST IN PERSONAL COMPUTERS.  HOW DOES IT COMPARE TO YOUR INTEREST AND PREFERENCE?"},
#   3383: {'filename': '3/sw3383',
#    'talk_day': datetime.datetime(1991, 11, 11, 0, 0),
#    'topic_description': 'AUTO REPAIRS',
#    'length': 5,
#    'prompt': 'WHAT WAS THE LAST AUTO REPAIR YOU PERFORMED OR HAD DONE ON YOUR CAR? ARE THERE SOME TYPES OF REPAIRS OR MAINTENANCE TASKS YOU PREFER TO DO YOURSELF?  DISCUSS YOUR EXPERIENCES IN THIS AREA WITH THE OTHER CALLER.'},
#   3454: {'filename': '3/sw3454',
#    'talk_day': datetime.datetime(1991, 12, 4, 0, 0),
#    'topic_description': 'SOCIAL CHANGE',
#    'length': 5,
#    'prompt': 'DISCUSS RECENT SOCIAL CHANGES.  HOW IS LIFE IN AMERICA DIFFERENT TODAY COMPARED TO LIVING TENY'},
#   3457: {'filename': '3/sw3457',
#    'talk_day': datetime.datetime(1991, 12, 5, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 5,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   3460: {'filename': '3/sw3460',
#    'talk_day': datetime.datetime(1991, 12, 5, 0, 0),
#    'topic_description': 'RIGHT TO PRIVACY',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT EVERYDAY OCCURRENCES THE OTHER CALLER CONSIDERS TO BE AN INTRUSION OF PRIVACY.  WHAT CAN BE DONE TO PREVENT THEM?  DO YOU AGREE OR DISAGREE?'},
#   3489: {'filename': '3/sw3489',
#    'talk_day': datetime.datetime(1991, 12, 9, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   3521: {'filename': '3/sw3521',
#    'talk_day': datetime.datetime(1991, 12, 12, 0, 0),
#    'topic_description': 'NEWS MEDIA',
#    'length': 5,
#    'prompt': 'DISCUSS HOW YOU AND THE OTHER CALLER KEEP UP ON CURRENT EVENTS.      DO YOU GET MOST OF YOUR NEWS FROM TVOR PEOPLE YOU KNOW?  ARE YOU SATISFIED WITH THE QUALITY OF COVERAGE?'},
#   3709: {'filename': '3/sw3709',
#    'talk_day': datetime.datetime(1992, 1, 9, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 5,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   3734: {'filename': '3/sw3734',
#    'talk_day': datetime.datetime(1992, 1, 12, 0, 0),
#    'topic_description': 'CLOTHING AND DRESS',
#    'length': 5,
#    'prompt': 'THE TOPIC IS CLOTHING.  PLEASE FIND OUT HOW THE OTHER CALLER TYPICALLY DRESSES FOR WORK.  HOW MUCH VARIATION IS THERE FROM DAY TO DAY?  HOW MUCH VARIATION IS THERE FROM SEASON TO SEASON?'},
#   3735: {'filename': '3/sw3735',
#    'talk_day': datetime.datetime(1992, 1, 13, 0, 0),
#    'topic_description': 'HOBBIES AND CRAFTS',
#    'length': 5,
#    'prompt': 'WHAT HOBBIES DO YOU HAVE IN YOUR SPARE TIME?  DO THEY INCLUDE ANY HANDICRAFTSWOODWORKING?'},
#   3751: {'filename': '3/sw3751',
#    'talk_day': datetime.datetime(1992, 1, 14, 0, 0),
#    'topic_description': 'CREDIT CARD USE',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CREDIT CARDS.  FIND OUT HOW THE OTHER CALLER MAKES USE OF CREDIT CARDS.  HOW DO THEY COMPARE TO YOUR OWN?'},
#   3770: {'filename': '3/sw3770',
#    'talk_day': datetime.datetime(1992, 1, 16, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   3847: {'filename': '3/sw3847',
#    'talk_day': datetime.datetime(1992, 1, 25, 0, 0),
#    'topic_description': 'GARDENING',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER DOES IN THE WAY OF LAWN AND GARDEN WORK.DOES THE OTHER CALL ENJOY DOING IT?  COMPARE THIS TO YOUR OWN SITUATION.'},
#   4716: {'filename': '4/sw4716',
#    'talk_day': datetime.datetime(1992, 4, 16, 0, 0),
#    'topic_description': 'GUN CONTROL',
#    'length': 5,
#    'prompt': 'DISCUSS GUN CONTROL.  WHERE DO YOU AND THE OTHER CALLER STAND ON A SCALE FROM 1 TO 10'},
#   2237: {'filename': '2/sw2237',
#    'talk_day': datetime.datetime(1991, 3, 25, 0, 0),
#    'topic_description': 'GARDENING',
#    'length': 10,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER DOES IN THE WAY OF LAWN AND GARDEN WORK.DOES THE OTHER CALL ENJOY DOING IT?  COMPARE THIS TO YOUR OWN SITUATION.'},
#   2263: {'filename': '2/sw2263',
#    'talk_day': datetime.datetime(1991, 3, 26, 0, 0),
#    'topic_description': 'CAMPING',
#    'length': 10,
#    'prompt': 'FIND OUT FROM THE OTHER CALLER WHAT KIND OF CAMPING THEY HAVE DONE.  HOW DOES IT COMPARE WITH YOUR OWN EXPERIENCES?'},
#   2323: {'filename': '2/sw2323',
#    'talk_day': datetime.datetime(1991, 3, 28, 0, 0),
#    'topic_description': 'SOVIET UNION',
#    'length': 6,
#    'prompt': 'FIND OUT WHETHER OR NOT THE OTHER CALLER CONSIDERS THE SOVIET UNION A THREAT TO THE UNITED STATES.   TAKE AN OPPOSING VIEW IN YOUR DISCUSSION WITH THE OTHER CALLER.'},
#   2340: {'filename': '2/sw2340',
#    'talk_day': datetime.datetime(1991, 3, 28, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 7,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   2413: {'filename': '2/sw2413',
#    'talk_day': datetime.datetime(1991, 4, 3, 0, 0),
#    'topic_description': 'POLITICS',
#    'length': 10,
#    'prompt': 'DISCUSS ANY RECENT POLITICAL ELECTIONS OR MOVEMENT THAT YOU AND THE OTHER CALLER CONSIDER INTERESTING OR IMPORTANT.  ORY'},
#   2578: {'filename': '2/sw2578',
#    'talk_day': datetime.datetime(1991, 4, 12, 0, 0),
#    'topic_description': 'BOOKS AND LITERATURE',
#    'length': 6,
#    'prompt': 'FIND OUT WHAT BOOKS THE OTHER CALLER READS FOR ENJOYMENT OR SELF-IMPROVEMENT.         DO YOU HAVE SIMILAR OR DIFFERENT INTERESTS IN BOOKS?'},
#   2773: {'filename': '2/sw2773',
#    'talk_day': datetime.datetime(1991, 5, 3, 0, 0),
#    'topic_description': 'MIDDLE EAST',
#    'length': 9,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THINKS ABOUT CURRENT US POLICY IN THE MIDDLE EAST. SHOULD US POLICY BE CHANGED OR NOT?'},
#   2839: {'filename': '2/sw2839',
#    'talk_day': datetime.datetime(1991, 5, 9, 0, 0),
#    'topic_description': 'TAXES',
#    'length': 7,
#    'prompt': 'TALK ABOUT WHETHER AMERICANSY'},
#   2862: {'filename': '2/sw2862',
#    'talk_day': datetime.datetime(1991, 5, 12, 0, 0),
#    'topic_description': 'BASKETBALL',
#    'length': 10,
#    'prompt': "FIND OUT THE OTHER CALLER'S FAVORITE PRO BASKETBALL TEAM AND WHERE IT'S HEADED THIS YEAR.  DO YOU AGREE WITH THE CALLER'S PREDICTION?"},
#   2934: {'filename': '2/sw2934',
#    'talk_day': datetime.datetime(1991, 5, 21, 0, 0),
#    'topic_description': 'WEATHER CLIMATE',
#    'length': 8,
#    'prompt': "DISCUSS THE WEATHER.   WHAT HAS IT BEEN LIKE IN YOUR AREA?   HAS IT BEEN TYPICAL FOR THIS TIME OF YEAR?  COMPARE IT WITH THE OTHER CALLER'S WEATHER."},
#   2942: {'filename': '2/sw2942',
#    'talk_day': datetime.datetime(1991, 5, 22, 0, 0),
#    'topic_description': 'CHOOSING A COLLEGE',
#    'length': 10,
#    'prompt': 'WHAT ADVICE OR EXPERIENCE CAN YOU OFFER TO A PARENT ON HOW TO HELP A SON OR DAUGHTER CHOOSE A COLLEGE TO ATTEND?'},
#   3009: {'filename': '3/sw3009',
#    'talk_day': datetime.datetime(1991, 6, 4, 0, 0),
#    'topic_description': 'CHILD CARE',
#    'length': 7,
#    'prompt': 'FIND OUT WHAT CRITERIA THE OTHER CALLER WOULD USE IN SELECTING CHILD CARE SERVICES FOR A PRESCHOOLER.  IS IT EASY OR DIFFICULT TO FIND SUCH CARE?'},
#   3046: {'filename': '3/sw3046',
#    'talk_day': datetime.datetime(1991, 6, 11, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 8,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   3104: {'filename': '3/sw3104',
#    'talk_day': datetime.datetime(1991, 6, 21, 0, 0),
#    'topic_description': 'CHOOSING A COLLEGE',
#    'length': 7,
#    'prompt': 'WHAT ADVICE OR EXPERIENCE CAN YOU OFFER TO A PARENT ON HOW TO HELP A SON OR DAUGHTER CHOOSE A COLLEGE TO ATTEND?'},
#   3167: {'filename': '3/sw3167',
#    'talk_day': datetime.datetime(1991, 9, 26, 0, 0),
#    'topic_description': 'RECIPES/FOOD/COOKING',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS FOOD AND COOKING.  WHAT FOODS WOULD YOU INCLUDE IN THE MENU FOR A DINNER PARTY?  SHARE THE RECIPE FOR ONE OF THESE FOODS WITH THE OTHER CALLER.'},
#   3181: {'filename': '3/sw3181',
#    'talk_day': datetime.datetime(1991, 9, 30, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 5,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   3185: {'filename': '3/sw3185',
#    'talk_day': datetime.datetime(1991, 10, 1, 0, 0),
#    'topic_description': 'WEATHER CLIMATE',
#    'length': 5,
#    'prompt': "DISCUSS THE WEATHER.   WHAT HAS IT BEEN LIKE IN YOUR AREA?   HAS IT BEEN TYPICAL FOR THIS TIME OF YEAR?  COMPARE IT WITH THE OTHER CALLER'S WEATHER."},
#   3204: {'filename': '3/sw3204',
#    'talk_day': datetime.datetime(1991, 10, 4, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   3310: {'filename': '3/sw3310',
#    'talk_day': datetime.datetime(1991, 10, 24, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   3363: {'filename': '3/sw3363',
#    'talk_day': datetime.datetime(1991, 11, 6, 0, 0),
#    'topic_description': 'BUYING A CAR',
#    'length': 5,
#    'prompt': "WHAT KIND OF CAR DO YOU THINK YOU MIGHT BUY NEXT?  WHAT SORTS OF THINGS WILL ENTER INTO YOUR DECISION?  SEE IF YOUR REQUIREMENTS AND THE OTHER CALLER'S REQUIREMENTS ARE SIMILAR."},
#   3414: {'filename': '3/sw3414',
#    'talk_day': datetime.datetime(1991, 11, 19, 0, 0),
#    'topic_description': 'RECYCLING',
#    'length': 5,
#    'prompt': 'WHAT IS BEING DONE IN YOUR COMMUNITY OR AREA ABOUT RECYCLING WASTE MATERIALS?  DO YOU THINK MORE SHOULD BE DONE?  DO YOU HAVE ANY IDEAS ON HOW TO ENCOURAGE MORE RECYCLING OR ON WHAT OTHER MATERIALS SHOULD BE INCLUDED?'},
#   3428: {'filename': '3/sw3428',
#    'talk_day': datetime.datetime(1991, 11, 25, 0, 0),
#    'topic_description': 'GUN CONTROL',
#    'length': 5,
#    'prompt': 'DISCUSS GUN CONTROL.  WHERE DO YOU AND THE OTHER CALLER STAND ON A SCALE FROM 1 TO 10'},
#   3455: {'filename': '3/sw3455',
#    'talk_day': datetime.datetime(1991, 12, 4, 0, 0),
#    'topic_description': 'MOVIES',
#    'length': 5,
#    'prompt': 'FIND OUT WHAT THE OTHER CALLER THOUGHT ABOUT THE LAST FEW MOVIES THEY SAW. WHAT MOVIES HAVE YOU SEEN LATELY?'},
#   3518: {'filename': '3/sw3518',
#    'talk_day': datetime.datetime(1991, 12, 11, 0, 0),
#    'topic_description': 'GUN CONTROL',
#    'length': 5,
#    'prompt': 'DISCUSS GUN CONTROL.  WHERE DO YOU AND THE OTHER CALLER STAND ON A SCALE FROM 1 TO 10'},
#   3570: {'filename': '3/sw3570',
#    'talk_day': datetime.datetime(1991, 12, 16, 0, 0),
#    'topic_description': 'SPACE FLIGHT AND EXPLORATION',
#    'length': 5,
#    'prompt': 'WHAT DO WE GAIN FROM OUR SPACE FLIGHT AND EXPLORATION EFFORTS? SHOULD WE CONTINUE TO SUPPORT THE SPACE PROGRAM AT CURRENT LEVELS? YOU MIGHT ALSO DISCUSS WHETHER SPACE FLIGHT WILL EVER BECOME COMMONYOU'},
#   3692: {'filename': '3/sw3692',
#    'talk_day': datetime.datetime(1992, 1, 7, 0, 0),
#    'topic_description': 'FEDERAL BUDGET',
#    'length': 5,
#    'prompt': 'WHAT SHORT AND LONG-TERM STEPS DO YOU AND THE OTHER CALLER THINK SHOULD BE TAKEN TO IMPROVE THE US BUDGET?'},
#   3703: {'filename': '3/sw3703',
#    'talk_day': datetime.datetime(1992, 1, 8, 0, 0),
#    'topic_description': 'RESTAURANTS',
#    'length': 5,
#    'prompt': "WHAT KIND OF DINING OUT DO YOU ENJOY? WHAT THINGS DO YOU LOOK FOR IN A RESTAURANT THAT WOULD GET YOU TO GO BACK AGAIN?  SEE WHETHER THE OTHER CALLER'S PREFERENCES ARE SIMILAR TO YOURS."},
#   3855: {'filename': '3/sw3855',
#    'talk_day': datetime.datetime(1992, 1, 27, 0, 0),
#    'topic_description': 'CREDIT CARD USE',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS CREDIT CARDS.  FIND OUT HOW THE OTHER CALLER MAKES USE OF CREDIT CARDS.  HOW DO THEY COMPARE TO YOUR OWN?'},
#   3952: {'filename': '3/sw3952',
#    'talk_day': datetime.datetime(1992, 2, 11, 0, 0),
#    'topic_description': 'EXERCISE AND FITNESS',
#    'length': 3,
#    'prompt': 'DO YOU DO ANY EXERCISE REGULARLY TO MAINTAIN YOUR HEALTH OR FITNESS LEVEL?  IF SOOR DO IT AS A TASK?  COMPARE YOUR HABITS AND YOUR MOTIVES'},
#   3965: {'filename': '3/sw3965',
#    'talk_day': datetime.datetime(1992, 2, 14, 0, 0),
#    'topic_description': 'WOODWORKING',
#    'length': 5,
#    'prompt': 'PLEASE DISCUSS WOODWORKING. IS IT A HOBBY FOR YOUY'},
#   4644: {'filename': '4/sw4644',
#    'talk_day': datetime.datetime(1992, 4, 10, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 5,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   4735: {'filename': '4/sw4735',
#    'talk_day': datetime.datetime(1992, 4, 18, 0, 0),
#    'topic_description': 'UNIVERSAL PBLIC SERV',
#    'length': 5,
#    'prompt': 'SEE HOW THE OTHER CALLER FEELS ABOUT THE PROPOSAL THAT ALL YOUNG AMERICANS SHOULD SPEND A YEAR OR TWO DOING SOME KIND OF PUBLIC SERVICE'},
#   4745: {'filename': '4/sw4745',
#    'talk_day': datetime.datetime(1992, 4, 20, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 5,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   2155: {'filename': '2/sw2155',
#    'talk_day': datetime.datetime(1991, 3, 13, 0, 0),
#    'topic_description': 'CARE OF THE ELDERLY',
#    'length': 10,
#    'prompt': 'PLEASE DISCUSS CARE OF THE ELDERLY.  FIND OUT HOW THE OTHER CALLER FEELS ABOUT SENDING AN ELDERLY FAMILY MEMBER TO A NURSING HOME.  WHAT SHOULD ONE KNOW ABOUT THE NURSING HOME ENVIRONMENT WHEN MAKING THIS DECISION?'},
#   2175: {'filename': '2/sw2175',
#    'talk_day': datetime.datetime(1991, 3, 18, 0, 0),
#    'topic_description': 'FAMILY LIFE',
#    'length': 10,
#    'prompt': 'IF YOU HAVE CHILDRENY'},
#   2227: {'filename': '2/sw2227',
#    'talk_day': datetime.datetime(1991, 3, 24, 0, 0),
#    'topic_description': 'TV PROGRAMS',
#    'length': 8,
#    'prompt': "FIND OUT WHAT THE OTHER CALLER'S FAVORITE TV SHOWS ARE AND WHY.  ARE YOUR INTERESTS SIMILAR OR DIFFERENT?"},
#   2292: {'filename': '2/sw2292',
#    'talk_day': datetime.datetime(1991, 3, 27, 0, 0),
#    'topic_description': 'JOB BENEFITS',
#    'length': 9,
#    'prompt': 'WHAT DO YOU CONSIDER THE MOST IMPORTANT BENEFITS BESIDES SALARY IN A JOB WITH A LARGE ORGANIZATION?  HOW SATISFIED ARE YOU WITH THE CURRENT BENEFITS OF YOUR JOB'},
#   ...}}

# %% [markdown]
# #### Saving created corpus

# %%
swda_corpus.dump("swda-corpus", base_path = "./datasets")

# %% [markdown]
# Check if available info from dataset can be checked directly

# %%
from convokit import meta_index
meta_index(filename = "./datasets/swda-corpus")
# Out:
# {'utterances-index': {'tag': "<class 'str'>", 'pos': "<class 'str'>"},
#  'users-index': {'sex': "<class 'str'>",
#   'education': "<class 'int'>",
#   'birth_year': "<class 'int'>",
#   'dialect_area': "<class 'str'>"},
#  'conversations-index': {},
#  'overall-index': {'name': "<class 'str'>", 'metadata': 'bin'},
#  'version': 1}
